# %% [markdown]
# <a href="https://colab.research.google.com/github/Pramodgopinathan/DATA_MINING-Frequent-Patterns/blob/main/Aprior.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
df = pd.read_excel('/Online Retail 1.xlsx')
df.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 9 columns]

# %%
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df
# Out:
#        InvoiceNo StockCode  ... CustomerID         Country
# 0         536365    85123A  ...    17850.0  United Kingdom
# 1         536365     71053  ...    17850.0  United Kingdom
# 2         536365    84406B  ...    17850.0  United Kingdom
# 3         536365    84029G  ...    17850.0  United Kingdom
# 4         536365    84029E  ...    17850.0  United Kingdom
# ...          ...       ...  ...        ...             ...
# 541904    581587     22613  ...    12680.0          France
# 541905    581587     22899  ...    12680.0          France
# 541906    581587     23254  ...    12680.0          France
# 541907    581587     23255  ...    12680.0          France
# 541908    581587     22138  ...    12680.0          France
#
# [541909 rows x 9 columns]

# %%
basket = (df[df['Country'] == "France"]
	.groupby(['InvoiceNo','Description'])['Quantity']
	.sum().unstack().reset_index().fillna(0)
	.set_index('InvoiceNo'))
basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                            ...
# 536370                          0.0  ...                              0.0
# 536852                          0.0  ...                              0.0
# 536974                          0.0  ...                              0.0
# 537065                          0.0  ...                              0.0
# 537463                          0.0  ...                              0.0
# ...                             ...  ...                              ...
# C579532                         0.0  ...                              0.0
# C579562                         0.0  ...                              0.0
# C580161                         0.0  ...                              0.0
# C580263                         0.0  ...                              0.0
# C581316                         0.0  ...                              0.0
#
# [461 rows x 1564 columns]

# %%
def encode_units(x):
	if x <= 0:
		return 0
	if x >= 1:
		return 1
basket_sets = basket.applymap(encode_units)
basket_sets.drop('POSTAGE',inplace=True, axis=1)
basket_sets
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                            ...
# 536370                            0  ...                                0
# 536852                            0  ...                                0
# 536974                            0  ...                                0
# 537065                            0  ...                                0
# 537463                            0  ...                                0
# ...                             ...  ...                              ...
# C579532                           0  ...                                0
# C579562                           0  ...                                0
# C580161                           0  ...                                0
# C580263                           0  ...                                0
# C581316                           0  ...                                0
#
# [461 rows x 1563 columns]

# %%
frequent_itemsets = apriori(basket_sets, min_support = 0.03, use_colnames = True)
rules = association_rules(frequent_itemsets, metric='confidence', min_threshold=1)
rules
# Out:
#                                           antecedents  ... conviction
# 0   (CHARLOTTE BAG DOLLY GIRL DESIGN, PLASTERS IN ...  ...        inf
# 1   (MINI PAINT SET VINTAGE, SET/20 RED RETROSPOT ...  ...        inf
# 2   (MINI PAINT SET VINTAGE, SET/20 RED RETROSPOT ...  ...        inf
# 3   (MINI PAINT SET VINTAGE, SET/6 RED SPOTTY PAPE...  ...        inf
# 4   (MINI PAINT SET VINTAGE, SET/6 RED SPOTTY PAPE...  ...        inf
# 5   (PACK OF 20 SKULL PAPER NAPKINS, SET/6 RED SPO...  ...        inf
# 6   (PACK OF 20 SKULL PAPER NAPKINS, SET/6 RED SPO...  ...        inf
# 7   (PACK OF 6 SKULL PAPER CUPS, SET/6 RED SPOTTY ...  ...        inf
# 8   (SET/6 RED SPOTTY PAPER CUPS, PACK OF 6 SKULL ...  ...        inf
# 9   (PACK OF 6 SKULL PAPER PLATES, SET/6 RED SPOTT...  ...        inf
# 10  (SET/6 RED SPOTTY PAPER CUPS, SET OF 9 BLACK S...  ...        inf
# 11  (SET OF 9 BLACK SKULL BALLOONS, SET/6 RED SPOT...  ...        inf
# ...
